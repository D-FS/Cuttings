# %% [markdown]
# # Included ellipsoid notebook

# %%
import numpy as np
import basic_functions as bf
import test_image_ellipsoid as tie
import bounding_box as bbox
import plot
import included_ellipsoid as ie
import scipy as scipy
from scipy import optimize
from scipy.optimize import minimize

# %% [markdown]
# ## Test with small noise

# %% [markdown]
# Creation of an ellipsoidal test image with a = 100, b = 50, c = 30 and a noise amplitude of 5.
# The produced cloud of points is rotated by an angle of pi/7 around the x axis et pi/6 around the y axis

# %%
test_image_coord = tie.ellipsoid_test_image(10000, 100., 50., 30., 5., np.pi/7., np.pi/6.)
plot.bbox_plot(test_image_coord, np.pi/7., np.pi/6., 2)

# %%
ie.included_ellipsoid_optim(test_image_coord, 1e-3)
# Out:
# bouding box optimiztation:
#        fun: 1376114.1778561268
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([56765.67088813, 70702.14487612])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 150
#       nit: 12
#    status: 0
#   success: True
#         x: array([-0.45216871, -0.54101609])
# a =  85.36902460478268 b =  43.42854253813174 c =  27.15536126079745
# volume = 421715.698574611
# (421715.698574611, 85.36902460478268, 43.42854253813174, 27.15536126079745)

# %% [markdown]
# ## Test with big noise

# %% [markdown]
# Creation of an ellipsoidal test image with a = 100, b = 50, c = 30 and a noise amplitude of 30.
# The produced cloud of points is rotated by an angle of pi/7 around the x axis et pi/6 around the y axis

# %%
test_image_coord = tie.ellipsoid_test_image(10000, 100., 50., 30., 30., np.pi/7., np.pi/6.)
plot.bbox_plot(test_image_coord, np.pi/7., np.pi/6., 2)

# %%
ie.included_ellipsoid_optim(test_image_coord, 1e-3)
# Out:
# bouding box optimiztation:
#        fun: 2626406.676664586
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-96842.64659882,  84779.64438498])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 285
#       nit: 20
#    status: 0
#   success: True
#         x: array([-0.4659077 , -0.50708462])
# a =  33.23992973335609 b =  18.87710688285385 c =  13.072054281516426
# volume = 34358.0085768468
# (34358.0085768468, 33.23992973335609, 18.87710688285385, 13.072054281516426)

# %% [markdown]
# ## Test with ultra-big noise

# %% [markdown]
# Creation of an ellipsoidal test image with a = 100, b = 50, c = 30 and a noise amplitude of 1000.
# The produced cloud of points is rotated by an angle of pi/7 around the x axis et pi/6 around the y axis

# %%
test_image_coord = tie.ellipsoid_test_image(10000, 100., 50., 30., 1000., np.pi/7., np.pi/6.)
plot.bbox_plot(test_image_coord, np.pi/7., np.pi/6., 2)

# %%
ie.included_ellipsoid_optim(test_image_coord, 1e-3)
# Out:
# bouding box optimiztation:
#        fun: 1353114671.433772
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-5.04389286e+08, -5.29010296e+07])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 240
#       nit: 16
#    status: 0
#   success: True
#         x: array([-0.45276259, -0.52452607])
# a =  25.86695450856712 b =  23.68534369642832 c =  23.129288094740435
# volume = 59357.536110937144
# (59357.536110937144, 25.86695450856712, 23.68534369642832, 23.129288094740435)

# %% [markdown]
# ## Sphere Test

# %% [markdown]
# Creation of a spherical test image with a radius of 100 and a noise amplitude of 10.

# %%
test_image_coord = tie.ellipsoid_test_image(10000, 100., 100., 100., 10., 0., 0.)
plot.bbox_plot(test_image_coord, 0., 0., 2)

# %%
ie.included_ellipsoid_optim(test_image_coord, 1e-3)
# Out:
# bouding box optimiztation:
#        fun: 9065312.203576127
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([541119.83627081, 191919.50559616])
#   message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#      nfev: 144
#       nit: 7
#    status: 0
#   success: True
#         x: array([-0.03509627, -0.10309386])
# a =  91.18930683747305 b =  92.10847241737574 c =  92.3368329082763
# volume = 3248681.071507583
# (3248681.071507583, 91.18930683747305, 92.10847241737574, 92.3368329082763)
